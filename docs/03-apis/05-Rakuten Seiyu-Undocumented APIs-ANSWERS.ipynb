# %% [markdown]
# # Rakuten Seiyu - undocumented APIs
#
# Some website secretly use APIs to get information. You can [find the APIs](https://inspectelement.org/apis.html#tutorial) and use them for yourself!
#
# As an example, let's find the prices of vegetables from [Rakuten Seiyu](https://sm.rakuten.co.jp/search/110000?l-id=_leftnavi_110000&sort=1), which is *not* part of the Rakuten API.

# %%
import requests

response = requests.get("https://sm.rakuten.co.jp/api/search/v1/items?type=parts&hit=20&sort=1&category_code=110000&operation=ranking&_=1726788252230")
data = response.json()
data
# Out:
# {'success': True,
#  'success_message': 'succeed to execute [getItem]',
#  'total_hit': 166,
#  'ranking_list': [{'item_code': '8000001020016',
#    'no_tax_price': 219,
#    'in_tax_price': 236,
#    'stock_out_flg': 0,
#    'stock_count': 1710,
#    'max_purchasing_amount': 12,
#    'min_purchasing_limit': 0,
#    'catch_weight_flg': 0,
#    'set_item_flg': 0,
#    'tax_type': 1,
#    'tax_rate': 8,
#    'not_single_sale_flg': 0,
#    'in_favorite': False,
#    'item_name': '【超目玉】きゅうり',
#    'item_image_url': '//sm.r10s.jp/item/16/8000001020016.jpg',
#    'mark': ['', '41', '', ''],
#    'product_name': '福島・千葉県などの国内産',
#    'standard_name': '3本・1パック',
#    'jan_code': '8000001020016',
#    'department_code': '94',
#    'fineline_code': '8000',
#    'rank_count_datetime': '2024年09月24日(火)',
#    'count_ranking': 11,
#    'lasttime_count_ranking': 1,
#    'order_ranking': 1,
#    'lasttime_order_ranking': 25},
#   {'item_code': '8000001420397',
#    'no_tax_price': 169,
#    'in_tax_price': 182,
#    'stock_out_flg': 0,
#    'stock_count': 1067,
#    'max_purchasing_amount': 12,
#    'min_purchasing_limit': 0,
#    'catch_weight_flg': 0,
#    'set_item_flg': 0,
#    'tax_type': 1,
#    'tax_rate': 8,
#    'not_single_sale_flg': 0,
#    'in_favorite': False,
#    'item_name': '【超目玉】玉ねぎ',
#    'item_image_url': '//sm.r10s.jp/item/97/8000001420397.jpg',
#    'mark': ['', '41', '', ''],
#    'product_name': '北海道などの国内産',
#    'standard_name': '2個・１パック',
#    'jan_code': '8000001420397',
#    'department_code': '94',
#    'fineline_code': '8000',
#    'rank_count_datetime': '2024年09月24日(火)',
#    'count_ranking': 8,
#    'lasttime_count_ranking': 2,
#    'order_ranking': 2,
#    'lasttime_order_ranking': 26},
#   {'item_code': '8000001011021',
#    'no_tax_price': 359,
#    'in_tax_price': 387,
#    'stock_out_flg': 0,
#    'stock_count': 102,
#    'max_purchasing_amount': 12,
#    'min_purchasing_limit': 0,
#    'catch_weight_flg': 0,
#    'set_item_flg': 0,
#    'tax_type': 1,
#    'tax_rate': 8,
#    'not_single_sale_flg': 0,
#    'in_favorite': False,
#    'item_name': 'ミニトマト',
#    'item_image_url': '//sm.r10s.jp/item/21/8000001011021.jpg',
#    'mark': ['', '', '', ''],
#    'product_name': '福島・青森・北海道どの国内産',
#    'standard_name': '約150g・1パック',
#    'jan_code': '8000001011021',
#    'department_code': '94',
#    'fineline_code': '8000',
#    'rank_count_datetime': '2024年09月24日(火)',
#    'count_ranking': 69,
#    'lasttime_count_ranking': 4,
#    'order_ranking': 3,
#    'lasttime_order_ranking': 40},
#   {'item_code': '8000001290013',
#    'no_tax_price': 79,
#    'in_tax_price': 85,
#    'stock_out_flg': 0,
#    'stock_count': 820,
#    'max_purchasing_amount': 12,
#    'min_purchasing_limit': 0,
#    'catch_weight_flg': 0,
#    'set_item_flg': 0,
#    'tax_type': 1,
#    'tax_rate': 8,
#    'not_single_sale_flg': 0,
#    'in_favorite': False,
#    'item_name': '【超目玉】えのき茸',
#    'item_image_url': '//sm.r10s.jp/item/13/8000001290013.jpg',
#    'mark': ['', '41', '', ''],
#    'product_name': '長野・新潟県などの国内産',
#    'standard_name': '1パック',
#    'jan_code': '8000001290013',
#    'department_code': '94',
#    'fineline_code': '8000',
#    'rank_count_datetime': '2024年09月24日(火)',
#    'count_ranking': 4,
#    'lasttime_count_ranking': 9,
#    'order_ranking': 4,
#    'lasttime_order_ranking': 88},
#   {'item_code': '8000001490017',
#    'no_tax_price': 199,
#    'in_tax_price': 214,
#    'stock_out_flg': 0,
#    'stock_count': 202,
#    'max_purchasing_amount': 12,
#    'min_purchasing_limit': 0,
#    'catch_weight_flg': 0,
#    'set_item_flg': 0,
#    'tax_type': 1,
#    'tax_rate': 8,
#    'not_single_sale_flg': 0,
#    'in_favorite': False,
#    'item_name': '長ねぎ',
#    'item_image_url': '//sm.r10s.jp/item/17/8000001490017.jpg',
#    'mark': ['', '', '', ''],
#    'product_name': '長野県などの国内産',
#    'standard_name': '2本・1パック',
#    'jan_code': '8000001490017',
#    'department_code': '94',
#    'fineline_code': '8000',
#    'rank_count_datetime': '2024年09月24日(火)',
#    'count_ranking': 27,
#    'lasttime_count_ranking': 3,
#    'order_ranking': 5,
#    'lasttime_order_ranking': 37},
#   {'item_code': '8000001160019',
#    'no_tax_price': 249,
#    'in_tax_price': 268,
#    'stock_out_flg': 0,
#    'stock_count': 667,
#    'max_purchasing_amount': 12,
#    'min_purchasing_limit': 0,
#    'catch_weight_flg': 0,
#    'set_item_flg': 0,
#    'tax_type': 1,
#    'tax_rate': 8,
#    'not_single_sale_flg': 0,
#    'in_favorite': False,
#    'item_name': 'レタス',
#    'item_image_url': '//sm.r10s.jp/item/19/8000001160019.jpg',
#    'mark': ['', '', '', ''],
#    'product_name': '群馬県などの国内産',
#    'standard_name': '1個',
#    'jan_code': '8000001160019',
#    'department_code': '94',
#    'fineline_code': '8000',
#    'rank_count_datetime': '2024年09月24日(火)',
#    'count_ranking': 70,
#    'lasttime_count_ranking': 6,
#    'order_ranking': 6,
#    'lasttime_order_ranking': 68},
#   {'item_code': '8000001370012',
#    'no_tax_price': 199,
#    'in_tax_price': 214,
#    'stock_out_flg': 0,
#    'stock_count': 718,
#    'max_purchasing_amount': 12,
#    'min_purchasing_limit': 0,
#    'catch_weight_flg': 0,
#    'set_item_flg': 0,
#    'tax_type': 1,
#    'tax_rate': 8,
#    'not_single_sale_flg': 0,
#    'in_favorite': False,
#    'item_name': 'にんじん',
#    'item_image_url': '//sm.r10s.jp/item/12/8000001370012.jpg',
#    'mark': ['', '', '', ''],
#    'product_name': '青森・北海道などの国内産',
#    'standard_name': '1パック',
#    'jan_code': '8000001370012',
#    'department_code': '94',
#    'fineline_code': '8000',
#    'rank_count_datetime': '2024年09月24日(火)',
#    'count_ranking': 43,
#    'lasttime_count_ranking': 11,
#    'order_ranking': 7,
#    'lasttime_order_ranking': 94},
#   {'item_code': '8000001040014',
#    'no_tax_price': 199,
#    'in_tax_price': 214,
#    'stock_out_flg': 0,
#    'stock_count': 362,
#    'max_purchasing_amount': 12,
#    'min_purchasing_limit': 0,
#    'catch_weight_flg': 0,
#    'set_item_flg': 0,
#    'tax_type': 1,
#    'tax_rate': 8,
#    'not_single_sale_flg': 0,
#    'in_favorite': False,
#    'item_name': 'ピーマン',
#    'item_image_url': '//sm.r10s.jp/item/14/8000001040014.jpg',
#    'mark': ['', '', '', ''],
#    'product_name': '北海道・千葉県などの国内産',
#    'standard_name': '1パック',
#    'jan_code': '8000001040014',
#    'department_code': '94',
#    'fineline_code': '8000',
#    'rank_count_datetime': '2024年09月24日(火)',
#    'count_ranking': 46,
#    'lasttime_count_ranking': 7,
#    'order_ranking': 8,
#    'lasttime_order_ranking': 71},
#   {'item_code': '4973450153168',
#    'no_tax_price': 289,
#    'in_tax_price': 312,
#    'stock_out_flg': 0,
#    'stock_count': 124,
#    'max_purchasing_amount': 12,
#    'min_purchasing_limit': 0,
#    'catch_weight_flg': 0,
#    'set_item_flg': 0,
#    'tax_type': 1,
#    'tax_rate': 8,
#    'not_single_sale_flg': 0,
#    'in_favorite': False,
#    'item_name': 'みなさまのお墨付き 豚汁の具 （冷凍）',
#    'item_image_url': '//sm.r10s.jp/item/68/4973450153168.jpg',
#    'mark': ['', '', '', ''],
#    'product_name': '西友オリジナル',
#    'standard_name': '250g',
#    'jan_code': '4973450153168',
#    'department_code': '90',
#    'fineline_code': '0510',
#    'rank_count_datetime': '2024年09月24日(火)',
#    'count_ranking': 101,
#    'lasttime_count_ranking': 16,
#    'order_ranking': 9,
#    'lasttime_order_ranking': 136},
#   {'item_code': '8000001170018',
#    'no_tax_price': 259,
#    'in_tax_price': 279,
#    'stock_out_flg': 0,
#    'stock_count': 562,
#    'max_purchasing_amount': 12,
#    'min_purchasing_limit': 0,
#    'catch_weight_flg': 0,
#    'set_item_flg': 0,
#    'tax_type': 1,
#    'tax_rate': 8,
#    'not_single_sale_flg': 0,
#    'in_favorite': False,
#    'item_name': 'ブロッコリー',
#    'item_image_url': '//sm.r10s.jp/item/18/8000001170018.jpg',
#    'mark': ['', '', '', ''],
#    'product_name': '長野・北海道県などの国内産',
#    'standard_name': '1個',
#    'jan_code': '8000001170018',
#    'department_code': '94',
#    'fineline_code': '8000',
#    'rank_count_datetime': '2024年09月24日(火)',
#    'count_ranking': 89,
#    'lasttime_count_ranking': 10,
#    'order_ranking': 10,
#    'lasttime_order_ranking': 90},
#   {'item_code': '8000009001239',
#    'no_tax_price': 689,
#    'in_tax_price': 744,
#    'stock_out_flg': 0,
#    'stock_count': 5,
#    'max_purchasing_amount': 12,
#    'min_purchasing_limit': 0,
#    'catch_weight_flg': 0,
#    'set_item_flg': 0,
#    'tax_type': 1,
#    'tax_rate': 8,
#    'not_single_sale_flg': 0,
#    'in_favorite': False,
#    'item_name': '【掘り出し物】ミニトマト',
#    'item_image_url': '//sm.r10s.jp/item/39/8000009001239.jpg',
#    'mark': ['', '', '', ''],
#    'product_name': '福島・青森・北海道どの国内産',
#    'standard_name': '約300g・1パック',
#    'jan_code': '8000009001239',
#    'department_code': '94',
#    'fineline_code': '8000',
#    'rank_count_datetime': '2024年09月24日(火)',
#    'count_ranking': 424,
#    'lasttime_count_ranking': 24,
#    'order_ranking': 11,
#    'lasttime_order_ranking': 236},
#   {'item_code': '8000009001956',
#    'no_tax_price': 529,
#    'in_tax_price': 571,
#    'stock_out_flg': 0,
#    'stock_count': 203,
#    'max_purchasing_amount': 12,
#    'min_purchasing_limit': 0,
#    'catch_weight_flg': 0,
#    'set_item_flg': 0,
#    'tax_type': 1,
#    'tax_rate': 8,
#    'not_single_sale_flg': 0,
#    'in_favorite': False,
#    'item_name': '【掘り出し物】玉ねぎ',
#    'item_image_url': '//sm.r10s.jp/item/56/8000009001956.jpg',
#    'mark': ['', '', '', ''],
#    'product_name': '北海道などの国内産',
#    'standard_name': '約1800g・1パック',
#    'jan_code': '8000009001956',
#    'department_code': '94',
#    'fineline_code': '8000',
#    'rank_count_datetime': '2024年09月24日(火)',
#    'count_ranking': 284,
#    'lasttime_count_ranking': 5,
#    'order_ranking': 12,
#    'lasttime_order_ranking': 67},
#   {'item_code': '8000001420281',
#    'no_tax_price': 159,
#    'in_tax_price': 171,
#    'stock_out_flg': 0,
#    'stock_count': 464,
#    'max_purchasing_amount': 12,
#    'min_purchasing_limit': 0,
#    'catch_weight_flg': 0,
#    'set_item_flg': 0,
#    'tax_type': 1,
#    'tax_rate': 8,
#    'not_single_sale_flg': 0,
#    'in_favorite': False,
#    'item_name': '【超目玉】長芋',
#    'item_image_url': '//sm.r10s.jp/item/81/8000001420281.jpg',
#    'mark': ['', '41', '', ''],
#    'product_name': '青森県などの国内産',
#    'standard_name': '1パック',
#    'jan_code': '8000001420281',
#    'department_code': '94',
#    'fineline_code': '8000',
#    'rank_count_datetime': '2024年09月24日(火)',
#    'count_ranking': 41,
#    'lasttime_count_ranking': 31,
#    'order_ranking': 13,
#    'lasttime_order_ranking': 347},
#   {'item_code': '8000001420458',
#    'no_tax_price': 299,
#    'in_tax_price': 322,
#    'stock_out_flg': 0,
#    'stock_count': 190,
#    'max_purchasing_amount': 12,
#    'min_purchasing_limit': 0,
#    'catch_weight_flg': 0,
#    'set_item_flg': 0,
#    'tax_type': 1,
#    'tax_rate': 8,
#    'not_single_sale_flg': 0,
#    'in_favorite': False,
#    'item_name': 'なす',
#    'item_image_url': '//sm.r10s.jp/item/58/8000001420458.jpg',
#    'mark': ['', '', '', ''],
#    'product_name': '群馬県などの国内産',
#    'standard_name': '4~5本・1パック',
#    'jan_code': '8000001420458',
#    'department_code': '94',
#    'fineline_code': '8000',
#    'rank_count_datetime': '2024年09月24日(火)',
#    'count_ranking': 142,
#    'lasttime_count_ranking': 13,
#    'order_ranking': 14,
#    'lasttime_order_ranking': 116},
#   {'item_code': '8000009001055',
#    'no_tax_price': 249,
#    'in_tax_price': 268,
#    'stock_out_flg': 0,
#    'stock_count': 291,
#    'max_purchasing_amount': 12,
#    'min_purchasing_limit': 0,
#    'catch_weight_flg': 0,
#    'set_item_flg': 0,
#    'tax_type': 1,
#    'tax_rate': 8,
#    'not_single_sale_flg': 0,
#    'in_favorite': False,
#    'item_name': 'じゃがいも',
#    'item_image_url': '//sm.r10s.jp/item/55/8000009001055.jpg',
#    'mark': ['', '', '', ''],
#    'product_name': '北海道などの国内産',
#    'standard_name': '約500g・1パック',
#    'jan_code': '8000009001055',
#    'department_code': '94',
#    'fineline_code': '8000',
#    'rank_count_datetime': '2024年09月24日(火)',
#    'count_ranking': 108,
#    'lasttime_count_ranking': 15,
#    'order_ranking': 15,
#    'lasttime_order_ranking': 131},
#   {'item_code': '8000001091016',
#    'no_tax_price': 159,
#    'in_tax_price': 171,
#    'stock_out_flg': 0,
#    'stock_count': 561,
#    'max_purchasing_amount': 12,
#    'min_purchasing_limit': 0,
#    'catch_weight_flg': 0,
#    'set_item_flg': 0,
#    'tax_type': 1,
#    'tax_rate': 8,
#    'not_single_sale_flg': 0,
#    'in_favorite': False,
#    'item_name': '小松菜',
#    'item_image_url': '//sm.r10s.jp/item/16/8000001091016.jpg',
#    'mark': ['', '', '', ''],
#    'product_name': '茨城・千葉県などの国内産',
#    'standard_name': '1パック',
#    'jan_code': '8000001091016',
#    'department_code': '94',
#    'fineline_code': '8000',
#    'rank_count_datetime': '2024年09月24日(火)',
#    'count_ranking': 49,
#    'lasttime_count_ranking': 14,
#    'order_ranking': 16,
#    'lasttime_order_ranking': 126},
#   {'item_code': '8000009001581',
#    'no_tax_price': 179,
#    'in_tax_price': 193,
#    'stock_out_flg': 0,
#    'stock_count': 84,
#    'max_purchasing_amount': 12,
#    'min_purchasing_limit': 0,
#    'catch_weight_flg': 0,
#    'set_item_flg': 0,
#    'tax_type': 1,
#    'tax_rate': 8,
#    'not_single_sale_flg': 0,
#    'in_favorite': False,
#    'item_name': '【訳あり】にんじん',
#    'item_image_url': '//sm.r10s.jp/item/81/8000009001581.jpg',
#    'mark': ['', '', '', ''],
#    'product_name': '青森・北海道などの国内産',
#    'standard_name': '4本・1パック',
#    'jan_code': '8000009001581',
#    'department_code': '94',
#    'fineline_code': '8000',
#    'rank_count_datetime': '2024年09月24日(火)',
#    'count_ranking': 74,
#    'lasttime_count_ranking': 17,
#    'order_ranking': 17,
#    'lasttime_order_ranking': 168},
#   {'item_code': '8000009001048',
#    'no_tax_price': 549,
#    'in_tax_price': 592,
#    'stock_out_flg': 0,
#    'stock_count': 73,
#    'max_purchasing_amount': 12,
#    'min_purchasing_limit': 0,
#    'catch_weight_flg': 0,
#    'set_item_flg': 0,
#    'tax_type': 1,
#    'tax_rate': 8,
#    'not_single_sale_flg': 0,
#    'in_favorite': False,
#    'item_name': '【掘り出し物】じゃがいも',
#    'item_image_url': '//sm.r10s.jp/item/48/8000009001048.jpg',
#    'mark': ['', '', '', ''],
#    'product_name': '北海道などの国内産',
#    'standard_name': '約1200g・1パック',
#    'jan_code': '8000009001048',
#    'department_code': '94',
#    'fineline_code': '8000',
#    'rank_count_datetime': '2024年09月24日(火)',
#    'count_ranking': 476,
#    'lasttime_count_ranking': 22,
#    'order_ranking': 18,
#    'lasttime_order_ranking': 217},
#   {'item_code': '8000001061040',
#    'no_tax_price': 139,
#    'in_tax_price': 150,
#    'stock_out_flg': 0,
#    'stock_count': 1435,
#    'max_purchasing_amount': 12,
#    'min_purchasing_limit': 0,
#    'catch_weight_flg': 0,
#    'set_item_flg': 0,
#    'tax_type': 1,
#    'tax_rate': 8,
#    'not_single_sale_flg': 0,
#    'in_favorite': False,
#    'item_name': '【超目玉】オクラ',
#    'item_image_url': '//sm.r10s.jp/item/40/8000001061040.jpg',
#    'mark': ['', '41', '', ''],
#    'product_name': '香川・高知県などの国内産',
#    'standard_name': '1パック',
#    'jan_code': '8000001061040',
#    'department_code': '94',
#    'fineline_code': '8000',
#    'rank_count_datetime': '2024年09月24日(火)',
#    'count_ranking': 59,
#    'lasttime_count_ranking': 29,
#    'order_ranking': 19,
#    'lasttime_order_ranking': 317},
#   {'item_code': '8000001310018',
#    'no_tax_price': 99,
#    'in_tax_price': 106,
#    'stock_out_flg': 0,
#    'stock_count': 740,
#    'max_purchasing_amount': 12,
#    'min_purchasing_limit': 0,
#    'catch_weight_flg': 0,
#    'set_item_flg': 0,
#    'tax_type': 1,
#    'tax_rate': 8,
#    'not_single_sale_flg': 0,
#    'in_favorite': False,
#    'item_name': '舞茸',
#    'item_image_url': '//sm.r10s.jp/item/18/8000001310018.jpg',
#    'mark': ['', '', '', ''],
#    'product_name': '栃木・新潟県などの国内産',
#    'standard_name': '1パック',
#    'jan_code': '8000001310018',
#    'department_code': '94',
#    'fineline_code': '8000',
#    'rank_count_datetime': '2024年09月24日(火)',
#    'count_ranking': 26,
#    'lasttime_count_ranking': 23,
#    'order_ranking': 20,
#    'lasttime_order_ranking': 226}],
#  'base_category_model': {'category_code': '110000', 'category_name': '野菜'}}

# %%
import pandas as pd

df = pd.json_normalize(data['ranking_list'])
df
# Out:
#         item_code  no_tax_price  in_tax_price  stock_out_flg  stock_count  \
# 0   8000001020016           219           236              0         1710
# 1   8000001420397           169           182              0         1067
# 2   8000001011021           359           387              0          102
# 3   8000001290013            79            85              0          820
# 4   8000001490017           199           214              0          202
# 5   8000001160019           249           268              0          667
# 6   8000001370012           199           214              0          718
# 7   8000001040014           199           214              0          362
# 8   4973450153168           289           312              0          124
# 9   8000001170018           259           279              0          562
# 10  8000009001239           689           744              0            5
# 11  8000009001956           529           571              0          203
# 12  8000001420281           159           171              0          464
# 13  8000001420458           299           322              0          190
# 14  8000009001055           249           268              0          291
# 15  8000001091016           159           171              0          561
# 16  8000009001581           179           193              0           84
# 17  8000009001048           549           592              0           73
# 18  8000001061040           139           150              0         1435
# 19  8000001310018            99           106              0          740
#
#     max_purchasing_amount  min_purchasing_limit  catch_weight_flg  \
# 0                      12                     0                 0
# 1                      12                     0                 0
# 2                      12                     0                 0
# 3                      12                     0                 0
# 4                      12                     0                 0
# 5                      12                     0                 0
# 6                      12                     0                 0
# 7                      12                     0                 0
# 8                      12                     0                 0
# 9                      12                     0                 0
# 10                     12                     0                 0
# 11                     12                     0                 0
# 12                     12                     0                 0
# 13                     12                     0                 0
# 14                     12                     0                 0
# 15                     12                     0                 0
# 16                     12                     0                 0
# 17                     12                     0                 0
# 18                     12                     0                 0
# 19                     12                     0                 0
#
#     set_item_flg  tax_type  ...    product_name  standard_name       jan_code  \
# 0              0         1  ...    福島・千葉県などの国内産        3本・1パック  8000001020016
# 1              0         1  ...       北海道などの国内産        2個・１パック  8000001420397
# 2              0         1  ...  福島・青森・北海道どの国内産     約150g・1パック  8000001011021
# 3              0         1  ...    長野・新潟県などの国内産           1パック  8000001290013
# 4              0         1  ...       長野県などの国内産        2本・1パック  8000001490017
# 5              0         1  ...       群馬県などの国内産             1個  8000001160019
# 6              0         1  ...    青森・北海道などの国内産           1パック  8000001370012
# 7              0         1  ...   北海道・千葉県などの国内産           1パック  8000001040014
# 8              0         1  ...         西友オリジナル           250g  4973450153168
# 9              0         1  ...   長野・北海道県などの国内産             1個  8000001170018
# 10             0         1  ...  福島・青森・北海道どの国内産     約300g・1パック  8000009001239
# 11             0         1  ...       北海道などの国内産    約1800g・1パック  8000009001956
# 12             0         1  ...       青森県などの国内産           1パック  8000001420281
# 13             0         1  ...       群馬県などの国内産      4~5本・1パック  8000001420458
# 14             0         1  ...       北海道などの国内産     約500g・1パック  8000009001055
# 15             0         1  ...    茨城・千葉県などの国内産           1パック  8000001091016
# 16             0         1  ...    青森・北海道などの国内産        4本・1パック  8000009001581
# 17             0         1  ...       北海道などの国内産    約1200g・1パック  8000009001048
# 18             0         1  ...    香川・高知県などの国内産           1パック  8000001061040
# 19             0         1  ...    栃木・新潟県などの国内産           1パック  8000001310018
#
#    department_code fineline_code rank_count_datetime count_ranking  \
# 0               94          8000      2024年09月24日(火)            11
# 1               94          8000      2024年09月24日(火)             8
# 2               94          8000      2024年09月24日(火)            69
# 3               94          8000      2024年09月24日(火)             4
# 4               94          8000      2024年09月24日(火)            27
# 5               94          8000      2024年09月24日(火)            70
# 6               94          8000      2024年09月24日(火)            43
# 7               94          8000      2024年09月24日(火)            46
# 8               90          0510      2024年09月24日(火)           101
# 9               94          8000      2024年09月24日(火)            89
# 10              94          8000      2024年09月24日(火)           424
# 11              94          8000      2024年09月24日(火)           284
# 12              94          8000      2024年09月24日(火)            41
# 13              94          8000      2024年09月24日(火)           142
# 14              94          8000      2024年09月24日(火)           108
# 15              94          8000      2024年09月24日(火)            49
# 16              94          8000      2024年09月24日(火)            74
# 17              94          8000      2024年09月24日(火)           476
# 18              94          8000      2024年09月24日(火)            59
# 19              94          8000      2024年09月24日(火)            26
#
#    lasttime_count_ranking order_ranking lasttime_order_ranking
# 0                       1             1                     25
# 1                       2             2                     26
# 2                       4             3                     40
# 3                       9             4                     88
# 4                       3             5                     37
# 5                       6             6                     68
# 6                      11             7                     94
# 7                       7             8                     71
# 8                      16             9                    136
# 9                      10            10                     90
# 10                     24            11                    236
# 11                      5            12                     67
# 12                     31            13                    347
# 13                     13            14                    116
# 14                     15            15                    131
# 15                     14            16                    126
# 16                     17            17                    168
# 17                     22            18                    217
# 18                     29            19                    317
# 19                     23            20                    226
#
# [20 rows x 26 columns]

# %% [markdown]
# ## What if we want more?
#
# Our API request only returned 20 items... what if we want more? Can we see anything in the URL that might help us?

# %%
import requests
import pandas as pd

response = requests.get("https://sm.rakuten.co.jp/api/search/v1/items?type=parts&hit=100&sort=1&category_code=110000&operation=ranking&_=1726788252230")
data = response.json()

df = pd.json_normalize(data['ranking_list'])
df
# Out:
#         item_code  no_tax_price  in_tax_price  stock_out_flg  stock_count  \
# 0   8000001020016           219           236              0         1709
# 1   8000001420397           169           182              0         1067
# 2   8000001011021           359           387              0          102
# 3   8000001290013            79            85              0          818
# 4   8000001490017           199           214              0          201
# ..            ...           ...           ...            ...          ...
# 95  4973460600492           369           398              0           14
# 96  4908010381286           329           355              0           36
# 97  4560452798444           399           430              0           42
# 98  8000001062009           399           430              0            9
# 99  4980997440019           199           214              0          105
#
#     max_purchasing_amount  min_purchasing_limit  catch_weight_flg  \
# 0                      12                     0                 0
# 1                      12                     0                 0
# 2                      12                     0                 0
# 3                      12                     0                 0
# 4                      12                     0                 0
# ..                    ...                   ...               ...
# 95                     12                     0                 0
# 96                     12                     0                 0
# 97                     12                     0                 0
# 98                     12                     0                 0
# 99                     12                     0                 0
#
#     set_item_flg  tax_type  ...    product_name  standard_name       jan_code  \
# 0              0         1  ...    福島・千葉県などの国内産        3本・1パック  8000001020016
# 1              0         1  ...       北海道などの国内産        2個・１パック  8000001420397
# 2              0         1  ...  福島・青森・北海道どの国内産     約150g・1パック  8000001011021
# 3              0         1  ...    長野・新潟県などの国内産           1パック  8000001290013
# 4              0         1  ...       長野県などの国内産        2本・1パック  8000001490017
# ..           ...       ...  ...             ...            ...            ...
# 95             0         1  ...                           450g  4973460600492
# 96             0         1  ...                           200g  4908010381286
# 97             0         1  ...                           400g  4560452798444
# 98             0         1  ...       群馬県などの国内産           1パック  8000001062009
# 99             0         1  ...              国産           1パック  4980997440019
#
#    department_code fineline_code rank_count_datetime count_ranking  \
# 0               94          8000      2024年09月24日(火)            11
# 1               94          8000      2024年09月24日(火)             8
# 2               94          8000      2024年09月24日(火)            69
# 3               94          8000      2024年09月24日(火)             4
# 4               94          8000      2024年09月24日(火)            27
# ..             ...           ...                 ...           ...
# 95              90          5510      2024年09月24日(火)          2800
# 96              90          5510      2024年09月24日(火)          2593
# 97              90          5510      2024年09月24日(火)          2968
# 98              94          8000      2024年09月24日(火)          3041
# 99              94          2410      2024年09月24日(火)          1748
#
#    lasttime_count_ranking order_ranking lasttime_order_ranking
# 0                       1             1                     25
# 1                       2             2                     26
# 2                       4             3                     40
# 3                       9             4                     88
# 4                       3             5                     37
# ..                    ...           ...                    ...
# 95                    101            96                   2517
# 96                    109            97                   3113
# 97                    104            98                   2836
# 98                     88            99                   1904
# 99                    112           100                   3182
#
# [100 rows x 26 columns]
