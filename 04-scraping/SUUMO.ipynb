# %%
# https://suumo.jp/chintai/tokyo/sc_chiyoda/mansion/

# %%
from playwright.async_api import async_playwright
import pandas as pd
from io import StringIO

# Open browser
playwright = await async_playwright().start()
browser = await playwright.chromium.launch(headless=False)
page = await browser.new_page()

# Start from the first page
await page.goto("https://suumo.jp/jj/chintai/ichiran/FR301FC005/?sc=13101&ar=030&bs=040&sd=1&ta=13&ts=1")
# Out:
# <Response url='https://suumo.jp/jj/chintai/ichiran/FR301FC005/?sc=13101&ar=030&bs=040&sd=1&ta=13&ts=1' request=<Request url='https://suumo.jp/jj/chintai/ichiran/FR301FC005/?sc=13101&ar=030&bs=040&sd=1&ta=13&ts=1' method='GET'>>

# %%
from bs4 import BeautifulSoup
import pandas as pd

# Get the page content
html = await page.content()

# Parse the page content with BeautifulSoup
soup = BeautifulSoup(html, 'lxml')

properties = []

# Find all property listings
listings = soup.select('.js-property')

for listing in listings:
    name = listing.select_one('.property_inner-title a').text if listing.select_one('.property_inner-title a') else None
    rent = listing.select_one('.detailbox-property-point').text if listing.select_one('.detailbox-property-point') else None
    management_fee = listing.select_one('.detailbox-property--col1 div:nth-child(2)').text if listing.select_one('.detailbox-property--col1 div:nth-child(2)') else None
    deposit = listing.select_one('.detailbox-property--col2 div:nth-child(1)').text if listing.select_one('.detailbox-property--col2 div:nth-child(1)') else None
    key_money = listing.select_one('.detailbox-property--col2 div:nth-child(2)').text if listing.select_one('.detailbox-property--col2 div:nth-child(2)') else None
    layout = listing.select_one('.detailbox-property--col3 div:nth-child(1)').text if listing.select_one('.detailbox-property--col3 div:nth-child(1)') else None
    size = listing.select_one('.detailbox-property--col3 div:nth-child(2)').text if listing.select_one('.detailbox-property--col3 div:nth-child(2)') else None
    direction = listing.select_one('.detailbox-property--col3 div:nth-child(3)').text if listing.select_one('.detailbox-property--col3 div:nth-child(3)') else None
    age = listing.select_one('.detailbox-property--col4 div:nth-child(2)').text if listing.select_one('.detailbox-property--col4 div:nth-child(2)') else None
    address = listing.select_one('.detailbox-property--col4').text if listing.select_one('.detailbox-property--col4') else None
    station_info = listing.select_one('.detailnote-box').text if listing.select_one('.detailnote-box') else None
    agency_name = listing.select_one('.detailnote-box-item div:nth-child(1)').text if listing.select_one('.detailnote-box-item div:nth-child(1)') else None
    agency_phone = listing.select_one('.detailnote-box-item div:nth-child(2)').text if listing.select_one('.detailnote-box-item div:nth-child(2)') else None
    property_url = listing.select_one('.property_inner-title a')['href'] if listing.select_one('.property_inner-title a') else None

    properties.append({
        "Property Name": name,
        "Rent": rent,
        "Management Fee": management_fee,
        "Deposit": deposit,
        "Key Money": key_money,
        "Floor Plan": layout,
        "Area Size": size,
        "Direction": direction,
        "Building Age": age,
        "Address": address,
        "Station Info": station_info,
        "Agency Name": agency_name,
        "Agency Phone": agency_phone,
        "Property URL": f'https://suumo.jp{property_url}' if property_url else None
    })

# Convert to a DataFrame
df = pd.DataFrame(properties)
df.head()  # Display the first few rows to verify
# Out:
#      Property Name  Rent Management Fee Deposit Key Money Floor Plan  \
# 0      クラッシィハウス大手町  32万円     管理費 15000円   敷32万円     礼32万円       2LDK
# 1  ライオンズフォーシア神田須田町  23万円     管理費 20000円   敷23万円        礼-       2LDK
# 2  ライオンズフォーシア神田須田町  23万円     管理費 20000円   敷23万円        礼-       2LDK
# 3  ライオンズフォーシア神田須田町  23万円     管理費 20000円   敷23万円        礼-       2LDK
# 4  ライオンズフォーシア神田須田町  23万円     管理費 20000円   敷23万円        礼-       2LDK
#
#   Area Size Direction Building Age Address  \
# 0   54.13m2         東         None    None
# 1   45.57m2         南         None    None
# 2   45.57m2         南         None    None
# 3   45.57m2         南         None    None
# 4   45.57m2         南         None    None
#
#                                         Station Info Agency Name  \
# 0  \n東京メトロ半蔵門線/大手町駅 歩4分\n東京メトロ丸ノ内線/淡路町駅 歩6分\nＪＲ中央...        None
# 1  \nＪＲ山手線/秋葉原駅 歩5分\n東京メトロ銀座線/神田駅 歩6分\n都営新宿線/岩本町駅...        None
# 2  \nＪＲ山手線/秋葉原駅 歩5分\n東京メトロ銀座線/神田駅 歩6分\n都営新宿線/岩本町駅...        None
# 3  \nＪＲ山手線/秋葉原駅 歩5分\n東京メトロ銀座線/神田駅 歩6分\n都営新宿線/岩本町駅...        None
# 4  \nＪＲ山手線/秋葉原駅 歩5分\n東京メトロ銀座線/神田駅 歩6分\n都営新宿線/岩本町駅...        None
#
#            Agency Phone                               Property URL
# 0  (株)プライムコーポレーション都心営業部  https://suumo.jp/chintai/bc_100400768898/
# 1   (株)ユウキ・ホーム麻布十番網代公園店  https://suumo.jp/chintai/bc_100335153441/
# 2  (株)ユウキ・ホーム麻布十番サテライト店  https://suumo.jp/chintai/bc_100335153437/
# 3       (株)ユウキ・ホーム麻布十番店  https://suumo.jp/chintai/bc_100335153675/
# 4     そらうみリアルエステート(株)本店  https://suumo.jp/chintai/bc_100335156273/

# %%
from bs4 import BeautifulSoup
import pandas as pd

# Initialize an empty list to hold all the scraped properties
all_properties = []

# Start scraping from page 1
page_number = 1
while True:
    # Navigate to the next page
    url = f"https://suumo.jp/jj/chintai/ichiran/FR301FC005/?sc=13101&ar=030&bs=040&sd=1&ta=13&ts=1&page={page_number}"
    await page.goto(url)
    
    # Get the page content
    html = await page.content()
    
    # Parse with BeautifulSoup
    soup = BeautifulSoup(html, 'lxml')
    
    # Scrape the listings on the current page
    listings = soup.select('.js-property')
    
    # Check if there are any listings, if not break the loop
    if not listings:
        print(f"No more listings found. Stopping at page {page_number}.")
        break

    for listing in listings:
        name = listing.select_one('.property_inner-title a').text if listing.select_one('.property_inner-title a') else None
        rent = listing.select_one('.detailbox-property-point').text if listing.select_one('.detailbox-property-point') else None
        management_fee = listing.select_one('.detailbox-property--col1 div:nth-child(2)').text if listing.select_one('.detailbox-property--col1 div:nth-child(2)') else None
        deposit = listing.select_one('.detailbox-property--col2 div:nth-child(1)').text if listing.select_one('.detailbox-property--col2 div:nth-child(1)') else None
        key_money = listing.select_one('.detailbox-property--col2 div:nth-child(2)').text if listing.select_one('.detailbox-property--col2 div:nth-child(2)') else None
        layout = listing.select_one('.detailbox-property--col3 div:nth-child(1)').text if listing.select_one('.detailbox-property--col3 div:nth-child(1)') else None
        size = listing.select_one('.detailbox-property--col3 div:nth-child(2)').text if listing.select_one('.detailbox-property--col3 div:nth-child(2)') else None
        direction = listing.select_one('.detailbox-property--col3 div:nth-child(3)').text if listing.select_one('.detailbox-property--col3 div:nth-child(3)') else None
        age = listing.select_one('.detailbox-property--col4 div:nth-child(2)').text if listing.select_one('.detailbox-property--col4 div:nth-child(2)') else None
        address = listing.select_one('.detailbox-property--col4').text if listing.select_one('.detailbox-property--col4') else None
        station_info = listing.select_one('.detailnote-box').text if listing.select_one('.detailnote-box') else None
        agency_name = listing.select_one('.detailnote-box-item div:nth-child(1)').text if listing.select_one('.detailnote-box-item div:nth-child(1)') else None
        agency_phone = listing.select_one('.detailnote-box-item div:nth-child(2)').text if listing.select_one('.detailnote-box-item div:nth-child(2)') else None
        property_url = listing.select_one('.property_inner-title a')['href'] if listing.select_one('.property_inner-title a') else None

        all_properties.append({
            "Property Name": name,
            "Rent": rent,
            "Management Fee": management_fee,
            "Deposit": deposit,
            "Key Money": key_money,
            "Floor Plan": layout,
            "Area Size": size,
            "Direction": direction,
            "Building Age": age,
            "Address": address,
            "Station Info": station_info,
            "Agency Name": agency_name,
            "Agency Phone": agency_phone,
            "Property URL": f'https://suumo.jp{property_url}' if property_url else None
        })

    # Check if there's a "Next" button to continue paginating
    next_button = soup.select_one('a:contains("次へ")')
    if not next_button:
        print(f"Reached the last page at {page_number}.")
        break

    # Move to the next page
    page_number += 1

# Convert the data to a DataFrame
df = pd.DataFrame(all_properties)
df.head()  # Display the first few rows to verify
# Out:
# /Users/soma/.pyenv/versions/3.10.13/lib/python3.10/site-packages/soupsieve/css_parser.py:856: FutureWarning: The pseudo class ':contains' is deprecated, ':-soup-contains' should be used moving forward.
#   warnings.warn(  # noqa: B028
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[3], line 12
#       9 while True:
#      10     # Navigate to the next page
#      11     url = f"https://suumo.jp/jj/chintai/ichiran/FR301FC005/?sc=13101&ar=030&bs=040&sd=1&ta=13&ts=1&page={page_number}"
# ---> 12     await page.goto(url)
#      14     # Get the page content
#      15     html = await page.content()
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/playwright/async_api/_generated.py:8638, in Page.goto(self, url, timeout, wait_until, referer)
#    8577 async def goto(
#    8578     self,
#    8579     url: str,
#    (...)
#    8585     referer: typing.Optional[str] = None
#    8586 ) -> typing.Optional["Response"]:
#    8587     """Page.goto
#    8588
#    8589     Returns the main resource response. In case of multiple redirects, the navigation will resolve with the first
#    (...)
#    8634     Union[Response, None]
#    8635     """
#    8637     return mapping.from_impl_nullable(
# -> 8638         await self._impl_obj.goto(
#    8639             url=url, timeout=timeout, waitUntil=wait_until, referer=referer
#    8640         )
#    8641     )
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/playwright/_impl/_page.py:500, in Page.goto(self, url, timeout, waitUntil, referer)
#     493 async def goto(
#     494     self,
#     495     url: str,
#    (...)
#     498     referer: str = None,
#     499 ) -> Optional[Response]:
# --> 500     return await self._main_frame.goto(**locals_to_params(locals()))
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/playwright/_impl/_frame.py:145, in Frame.goto(self, url, timeout, waitUntil, referer)
#     135 async def goto(
#     136     self,
#     137     url: str,
#    (...)
#     140     referer: str = None,
#     141 ) -> Optional[Response]:
#     142     return cast(
#     143         Optional[Response],
#     144         from_nullable_channel(
# --> 145             await self._channel.send("goto", locals_to_params(locals()))
#     146         ),
#     147     )
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/playwright/_impl/_connection.py:59, in Channel.send(self, method, params)
#      58 async def send(self, method: str, params: Dict = None) -> Any:
# ---> 59     return await self._connection.wrap_api_call(
#      60         lambda: self.inner_send(method, params, False)
#      61     )
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/playwright/_impl/_connection.py:511, in Connection.wrap_api_call(self, cb, is_internal)
#     509 self._api_zone.set(parsed_st)
#     510 try:
# --> 511     return await cb()
#     512 except Exception as error:
#     513     print("ERROR IS", error)
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/playwright/_impl/_connection.py:88, in Channel.inner_send(self, method, params, return_as_dict)
#      84     raise error
#      85 callback = self._connection._send_message_to_server(
#      86     self._object, method, _filter_none(params)
#      87 )
# ---> 88 done, _ = await asyncio.wait(
#      89     {
#      90         self._connection._transport.on_error_future,
#      91         callback.future,
#      92     },
#      93     return_when=asyncio.FIRST_COMPLETED,
#      94 )
#      95 if not callback.future.done():
#      96     callback.future.cancel()
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/asyncio/tasks.py:384, in wait(fs, timeout, return_when)
#     377     warnings.warn("The explicit passing of coroutine objects to "
#     378                   "asyncio.wait() is deprecated since Python 3.8, and "
#     379                   "scheduled for removal in Python 3.11.",
#     380                   DeprecationWarning, stacklevel=2)
#     382 fs = {ensure_future(f, loop=loop) for f in fs}
# --> 384 return await _wait(fs, timeout, return_when, loop)
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/asyncio/tasks.py:491, in _wait(fs, timeout, return_when, loop)
#     488     f.add_done_callback(_on_completion)
#     490 try:
# --> 491     await waiter
#     492 finally:
#     493     if timeout_handle is not None:
#
# CancelledError:

# %%
pd.options.display.max_colwidth = 300

df = pd.DataFrame(all_properties)
df.head()  # Display the first few rows to verify
# Out:
#      Property Name  Rent Management Fee Deposit Key Money Floor Plan  \
# 0      クラッシィハウス大手町  32万円     管理費 15000円   敷32万円     礼32万円       2LDK
# 1  ライオンズフォーシア神田須田町  23万円     管理費 20000円   敷23万円        礼-       2LDK
# 2  ライオンズフォーシア神田須田町  23万円     管理費 20000円   敷23万円        礼-       2LDK
# 3  ライオンズフォーシア神田須田町  23万円     管理費 20000円   敷23万円        礼-       2LDK
# 4  ライオンズフォーシア神田須田町  23万円     管理費 20000円   敷23万円        礼-       2LDK
#
#   Area Size Direction Building Age Address  \
# 0   54.13m2         東         None    None
# 1   45.57m2         南         None    None
# 2   45.57m2         南         None    None
# 3   45.57m2         南         None    None
# 4   45.57m2         南         None    None
#
#                                                 Station Info Agency Name  \
# 0  \n東京メトロ半蔵門線/大手町駅 歩4分\n東京メトロ丸ノ内線/淡路町駅 歩6分\nＪＲ中央線/神田駅 歩8分\n        None
# 1       \nＪＲ山手線/秋葉原駅 歩5分\n東京メトロ銀座線/神田駅 歩6分\n都営新宿線/岩本町駅 歩6分\n        None
# 2       \nＪＲ山手線/秋葉原駅 歩5分\n東京メトロ銀座線/神田駅 歩6分\n都営新宿線/岩本町駅 歩6分\n        None
# 3       \nＪＲ山手線/秋葉原駅 歩5分\n東京メトロ銀座線/神田駅 歩6分\n都営新宿線/岩本町駅 歩6分\n        None
# 4       \nＪＲ山手線/秋葉原駅 歩5分\n東京メトロ銀座線/神田駅 歩6分\n都営新宿線/岩本町駅 歩6分\n        None
#
#            Agency Phone                               Property URL
# 0  (株)プライムコーポレーション都心営業部  https://suumo.jp/chintai/bc_100400768898/
# 1   (株)ユウキ・ホーム麻布十番網代公園店  https://suumo.jp/chintai/bc_100335153441/
# 2  (株)ユウキ・ホーム麻布十番サテライト店  https://suumo.jp/chintai/bc_100335153437/
# 3       (株)ユウキ・ホーム麻布十番店  https://suumo.jp/chintai/bc_100335153675/
# 4     そらうみリアルエステート(株)本店  https://suumo.jp/chintai/bc_100335156273/

# %%
df.to_csv("suumo-properties.csv", index=False)
